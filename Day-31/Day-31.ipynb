# %% [markdown]
# Đại khái là thư viện giúp chuyển đổi dữ liệu thành các ứng dụng phân tích trực quan

# %%
import pygwalker as pyg
import pandas as pd

# %%
FILE_PATH = 'D:/2024/AIO/Outside-Content/40-Days-Code/Day-31/advertising.csv'

# %%
data = pd.read_csv(FILE_PATH)
pyg.walk(data)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-00061507d9faa79fF9q67PGJ20ID5U4E" style="height: auto">\n    <head>…

# %% [markdown]
# Câu 1: Vẽ biểu đồ phân phối dữ liệu cho 3 loại: TV, Radio, Paper và được Color
# theo độ lớn của giá bán (Sales).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Câu 2: Vẽ biểu đồ cột thể hiện doanh số bán (Sales) ⩾ 10 của cả 3 loại TV,
# Radio và Newspaper.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Câu 3: Hãy vẽ bản đồ biểu diễn phân bố dân số theo thành phố của các nước
# thuộc các nước: Việt Nam, Hàn Quốc, Nhật Bản, Singapore và Thái Lan dựa
# theo dữ liệu sau: Dữ liệu dân số thế giới

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
FILE_PATH = 'D:/2024/AIO/Outside-Content/40-Days-Code/Day-31/worldcities.csv'

# %%
data = pd.read_csv(FILE_PATH)
pyg.walk(data)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-00061507e3aa7839S6tazjZF5pW04XPd" style="height: auto">\n    <head>…
